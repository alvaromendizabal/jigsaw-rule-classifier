# %% [markdown]
# # Round 7 — Matched opposing-support evidence
#
# A bounded CPU feature experiment. Reuse the completed Round 6 controls; no new encoder, download, blend or model search. This repeatedly inspected cohort is exploratory, not a Kaggle score.

# %%
from pathlib import Path
import json
import pandas as pd
from IPython.display import display
ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "configs/matched_support_features.json").is_file())
from scripts.run_matched_support_features import PUBLIC, figures, write_dashboard
result = json.loads((ROOT / PUBLIC / "results.json").read_text())
print("Run:", result["run_id"], "| Decision:", result["decision"])
print("New fits:", result["new_fits"], "| Prior readouts:", result["reused_prior_controls"])
CHARTS = figures(result)
# Out:
# Run: 6dacdcfb6a19ec13d83f | Decision: DO_NOT_PROMOTE_PRIMARY
# New fits: 12 | Prior readouts: 6

# %% [markdown]
# ## 1. Prior evidence and unchanged benchmark
#
# Round 6 local density did not improve basic geometry; no candidate was promoted. The current comparison retains the same raw Qwen/answer/basic references and exact query order. Local diagnostic scores must not be compared numerically with hidden Kaggle scores.

# %%
prior = json.loads((ROOT / "reports/local_support_features/results.json").read_text())
display(pd.DataFrame(prior["pooled_metrics"]))
display(pd.DataFrame(result["cohorts"]))
print("Reference prediction parity:", result["control_design_parity"])
# Out:
#         variant  macro_auc  pooled_auc  ranked_pooled_auc
# 0      qwen_raw   0.719893    0.739666           0.738959
# 1   answer_only   0.719893    0.738680           0.738959
# 2  frozen_basic   0.723068    0.733852           0.737090
# 3  frozen_local   0.714480    0.732433           0.731289
# 4    frozen_all   0.717513    0.733657           0.733572
# 5  shuffled_all   0.713916    0.727191           0.726985
# 6   adapted_all   0.719996    0.742625           0.741000
#                                               policy  \
# 0  No Advertising: Spam, referral links, unsolici...
# 1  No legal advice: Do not offer or request legal...
#
#    readiness_same_rule_novel  canonical_global_novel  \
# 0                        234                     234
# 1                        648                     647
#
#    cross_rule_support_exclusions  training_pairs  epoch_weight  \
# 0                              0            1640          2269
# ...

# %% [markdown]
# ## 2. Performance and uncertainty
#
# Do not select a new primary from this chart. paired_all was fixed before execution. Intervals are conditional on saved predictions and do not correct the entire adaptive research history.

# %%
display(pd.DataFrame(result["metrics"]))
CHARTS[0].show(renderer="plotly_mimetype")
CHARTS[1].show(renderer="plotly_mimetype")
# Out:
#     fold                                             policy           variant  \
# 0      0  No Advertising: Spam, referral links, unsolici...          qwen_raw
# 1      1  No legal advice: Do not offer or request legal...          qwen_raw
# 2      0  No Advertising: Spam, referral links, unsolici...       answer_only
# 3      1  No legal advice: Do not offer or request legal...       answer_only
# 4      0  No Advertising: Spam, referral links, unsolici...      frozen_basic
# 5      1  No legal advice: Do not offer or request legal...      frozen_basic
# 6      0  No Advertising: Spam, referral links, unsolici...     paired_global
# 7      1  No legal advice: Do not offer or request legal...     paired_global
# 8      0  No Advertising: Spam, referral links, unsolici...      paired_local
# 9      1  No legal advice: Do not offer or request legal...      paired_local
# 10     0  No Advertising: Spam, referral links, unsolici...        paired_all
# ...

# %% [markdown]
# ## 3. Paired direction, not just greater feature width
#
# Random re-pairing retains both endpoint sets but removes optimized links. Random orientation retains the matched midpoints and pair lengths but destroys the learned label direction. Raw versus unit differences test amplification by pair separation. These are null/sensitivity arms, not invented supervision.

# %%
display(pd.DataFrame(result["comparisons"]))
CHARTS[2].show(renderer="plotly_mimetype")
CHARTS[3].show(renderer="plotly_mimetype")
# Out:
#            candidate         reference  \
# 0      paired_global      frozen_basic
# 1       paired_local      frozen_basic
# 2         paired_all      frozen_basic
# 3       repaired_all      frozen_basic
# 4    orientation_all      frozen_basic
# 5   unnormalized_all      frozen_basic
# 6         paired_all          qwen_raw
# 7         paired_all       answer_only
# 8         paired_all      repaired_all
# 9         paired_all   orientation_all
# 10        paired_all  unnormalized_all
# 11        paired_all     paired_global
# 12        paired_all      paired_local
#
#                                      comparison  delta_auc  simultaneous_low  \
# 0               paired_global vs basic geometry  -0.002549         -0.015532
# 1                paired_local vs basic geometry  -0.000688         -0.013672
# 2                  paired_all vs basic geometry  -0.002186         -0.015170
# 3                repaired_all vs basic geometry  -0.004795         -0.017778
# ...

# %% [markdown]
# ## 4. Coverage and matching diagnostics
#
# Each selected reference is used in at most one pair. Similarity is a proxy, not evidence that pairs differ only in the rule-relevant behavior. Unused references, smaller cross-fit pools, and degenerate-pair exclusions are reported.

# %%
display(pd.DataFrame(result["pairing"]))
CHARTS[4].show(renderer="plotly_mimetype")
CHARTS[5].show(renderer="plotly_mimetype")
# Out:
#     fold   inner_fold          mode  self_text_overlap  reference_rows  \
# 0      0            0       matched                0.0             419
# 1      0            0      repaired                0.0             419
# 2      0            0   orientation                0.0             419
# 3      0            0  unnormalized                0.0             419
# 4      0            1       matched                0.0             419
# 5      0            1      repaired                0.0             419
# 6      0            1   orientation                0.0             419
# 7      0            1  unnormalized                0.0             419
# 8      0            2       matched                0.0             420
# 9      0            2      repaired                0.0             420
# 10     0            2   orientation                0.0             420
# 11     0            2  unnormalized                0.0             420
# ...

# %% [markdown]
# ## 5. Fitted effects and probability quality
#
# Coefficients are associations under the fixed readout. AUC may improve while Brier or log loss worsen. Cross-fitting new pair statistics does not turn the adapted training answer scores into out-of-fold encoder predictions.

# %%
CHARTS[6].show(renderer="plotly_mimetype")
CHARTS[7].show(renderer="plotly_mimetype")
display(pd.DataFrame(result["pooled_metrics"]))
# Out:
#             variant  macro_auc  pooled_auc  ranked_pooled_auc
# 0          qwen_raw   0.719893    0.739666           0.738959
# 1       answer_only   0.719893    0.738680           0.738959
# 2      frozen_basic   0.723068    0.733852           0.737090
# 3     paired_global   0.720518    0.734005           0.736241
# 4      paired_local   0.722379    0.735450           0.736958
# 5        paired_all   0.720881    0.735856           0.736589
# 6      repaired_all   0.718273    0.733251           0.733773
# 7   orientation_all   0.721683    0.734279           0.735956
# 8  unnormalized_all   0.721144    0.735128           0.736415

# %% [markdown]
# ## 6. Fixed primary and retained uncertainty
#
# Require +0.003 macro AUC, positive simultaneous lower bound, and no policy regression against five predeclared controls; ranked-pooled AUC cannot decline against Qwen. A development pass is eligibility only, not GPU authorization or a leaderboard improvement.

# %%
for requirement in result["primary_requirements"]:
    print(requirement["reference"], "| Passed:", requirement["passed"])
    display(pd.DataFrame([requirement["contrast"]]))
print("Decision:", result["decision"])
for limitation in result["limitations"]:
    print(limitation)
# Out:
# qwen_raw | Passed: False
#     candidate reference           comparison  delta_auc  simultaneous_low  \
# 0  paired_all  qwen_raw  Primary vs raw Qwen   0.000988         -0.011996
#
#    simultaneous_high
# 0           0.013971
# answer_only | Passed: False
#     candidate    reference                      comparison  delta_auc  \
# 0  paired_all  answer_only  Primary vs answer-only readout   0.000988
#
#    simultaneous_low  simultaneous_high
# 0         -0.011996           0.013971
# frozen_basic | Passed: False
#     candidate     reference                    comparison  delta_auc  \
# 0  paired_all  frozen_basic  paired_all vs basic geometry  -0.002186
#
#    simultaneous_low  simultaneous_high
# 0          -0.01517           0.010797
# repaired_all | Passed: False
#     candidate     reference                            comparison  delta_auc  \
# 0  paired_all  repaired_all  Similar pairing vs random re-pairing   0.002608
#
#    simultaneous_low  simultaneous_high
# ...

# %% [markdown]
# ## 7. Saved dashboard and next checkpoint
#
# Research basis: [Rule By Example](https://aclanthology.org/2023.acl-long.22/). This is an engineered contrast feature experiment, not a reproduction of its encoder training. Stop a negative direction, preserve its evidence, and choose a new hypothesis only after inspection. GitHub is not modified by this notebook.

# %%
print("Dashboard:", write_dashboard(ROOT, result))
print("Return the ZIP from your home folder: jigsaw_feature_round7_return.zip")
print("No prior round, neural model, or ensemble needs rerunning.")
# Out:
# Dashboard: /home/sagemaker-user/projects/jigsaw-rule-classifier/reports/matched_support_features/dashboard.html
# Return the ZIP from your home folder: jigsaw_feature_round7_return.zip
# No prior round, neural model, or ensemble needs rerunning.
