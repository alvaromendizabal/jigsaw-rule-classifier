# %% [markdown]
# # Round 5 — Occurrence-level lexical scope
#
# One bounded feature experiment. Twelve saved control fits reused; twelve new fits. No package installation, raw-data change, neural inference, AWS API call or submission. The repeatedly examined 881-comment cohort is exploratory.

# %%
from pathlib import Path
import json
import pandas as pd
from IPython.display import display
ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "configs/scope_lexical_features.json").is_file())
from scripts.run_scope_lexical_features import verify_prior, bounded_compute, figures, write_dashboard
config = json.loads((ROOT / "configs/scope_lexical_features.json").read_text())
print("Project:", ROOT)
print("Registered primary:", config["primary"])
print("New CPU fits:", config["new_fits"], "| Cached control fits:", config["cached_control_fits"])
# Out:
# Project: /home/sagemaker-user/projects/jigsaw-rule-classifier
# Registered primary: scope_both
# New CPU fits: 12 | Cached control fits: 12

# %% [markdown]
# ## 1. Previous evidence, without promotion
#
# Round 4 reached mean policy AUC 0.70225. Both policies improved, but its simultaneous intervals cross zero. Reuse this as an exploratory anchor, not a new accepted model.

# %%
older, fourth, directory4 = verify_prior(ROOT, config)
display(pd.DataFrame(fourth["metrics"]).query("variant in ['condition_lexical', 'rule_both', 'permuted_both']"))
print("Round 4 decision:", fourth["decision"])
print("All prior checkpoints verified; no old model refitted.")
# Out:
#     fold                                             policy  \
# 4      0  No Advertising: Spam, referral links, unsolici...
# 8      0  No Advertising: Spam, referral links, unsolici...
# 9      0  No Advertising: Spam, referral links, unsolici...
# 15     1  No legal advice: Do not offer or request legal...
# 19     1  No legal advice: Do not offer or request legal...
# 20     1  No legal advice: Do not offer or request legal...
#
#               variant       auc     brier  log_loss  queries
# 4   condition_lexical  0.686604  0.231335  0.669720      234
# 8           rule_both  0.688694  0.231786  0.670448      234
# 9       permuted_both  0.687052  0.231094  0.670799      234
# 15  condition_lexical  0.702432  0.230347  0.725947      647
# 19          rule_both  0.715798  0.223333  0.703677      647
# 20      permuted_both  0.703166  0.230431  0.727302      647
# Round 4 decision: DO_NOT_PROMOTE_PRIMARY
# All prior checkpoints verified; no old model refitted.

# %% [markdown]
# ## 2. New representation and exact magnitude control
#
# Attach the inherited word features to explicit authored/quoted/code contexts and approximate negation windows. Preserve each term's squared magnitude across contexts. Compare against equally wide collapsed controls. A negative instruction remains an instruction; this procedure never flips a moderation label.

# %%
result = bounded_compute(ROOT)
print("Decision:", result["decision"])
print("New fits:", result["new_fits"])
print("Reused controls:", result["reused_prior_controls"])
print("Reference prediction parity:", result["control_design_parity"])
CHARTS = figures(result)
# Out:
# {"timestamp": "2026-09-12T02:29:38+00:00", "stage": "scope_lexical_round5", "event": "started", "elapsed_seconds": 0.0, "stage_elapsed_seconds": 0.0, "total_elapsed_seconds": 0.0}
# {"timestamp": "2026-09-12T02:29:49+00:00", "stage": "scope_lexical_round5", "event": "all_control_designs_verified", "elapsed_seconds": 11.013, "stage_elapsed_seconds": 11.013, "total_elapsed_seconds": 11.013, "cached_controls": 12, "new_fits": 0}
# {"timestamp": "2026-09-12T02:29:50+00:00", "stage": "scope_lexical_round5", "event": "candidate_complete", "elapsed_seconds": 12.065, "stage_elapsed_seconds": 12.065, "total_elapsed_seconds": 12.065, "completed": 1, "total": 12, "fold": 0, "variant": "copy_attribution", "new_fits": 1, "reused_fits": 0}
# ...

# %% [markdown]
# ## 3. Policy results and conditional uncertainty
#
# Inspect both policies. The simultaneous intervals cover this round's planned comparisons only, not historical adaptive selection or future-policy uncertainty.

# %%
display(pd.DataFrame(result["metrics"]))
CHARTS[0].show(renderer="plotly_mimetype")
CHARTS[1].show(renderer="plotly_mimetype")
# Out:
#     fold                                             policy  \
# 0      0  No Advertising: Spam, referral links, unsolici...
# 1      0  No Advertising: Spam, referral links, unsolici...
# 2      0  No Advertising: Spam, referral links, unsolici...
# 3      0  No Advertising: Spam, referral links, unsolici...
# 4      0  No Advertising: Spam, referral links, unsolici...
# 5      0  No Advertising: Spam, referral links, unsolici...
# 6      0  No Advertising: Spam, referral links, unsolici...
# 7      0  No Advertising: Spam, referral links, unsolici...
# 8      0  No Advertising: Spam, referral links, unsolici...
# 9      0  No Advertising: Spam, referral links, unsolici...
# 10     0  No Advertising: Spam, referral links, unsolici...
# 11     0  No Advertising: Spam, referral links, unsolici...
# 12     1  No legal advice: Do not offer or request legal...
# 13     1  No legal advice: Do not offer or request legal...
# 14     1  No legal advice: Do not offer or request legal...
# ...

# %% [markdown]
# ## 4. Scope information versus scaling; family removal
#
# The primary must beat the current anchor AND its matched collapsed control. Removal contrasts measure the conditional contribution of the two feature families. Equal energy is not equal model capacity.

# %%
display(pd.DataFrame(result["comparisons"]).query("comparison.str.startswith('Scope versus')", engine="python"))
CHARTS[2].show(renderer="plotly_mimetype")
CHARTS[3].show(renderer="plotly_mimetype")
print("Per-term energy checks:", result["scope_energy_checks"])
# Out:
#                             comparison          candidate         reference  \
# 6  Scope versus collapsed: attribution  scope_attribution  copy_attribution
# 7     Scope versus collapsed: negation     scope_negation     copy_negation
# 8         Scope versus collapsed: both         scope_both         copy_both
#
#    delta_auc  simultaneous_low  simultaneous_high  valid_draws
# 6  -0.000465         -0.008493           0.007563          500
# 7   0.000205         -0.007823           0.008233          500
# 8  -0.000379         -0.008407           0.007650          500
# ...

# %% [markdown]
# ## 5. Scope coverage and real feature size
#
# Coverage uses observable text without targets. Many zero-padded columns are inactive; allocated width is not a count of useful features. Single-quoted and implicit reported speech remain known limitations.

# %%
display(pd.DataFrame(result["scope_coverage"]))
CHARTS[4].show(renderer="plotly_mimetype")
CHARTS[5].show(renderer="plotly_mimetype")
# Out:
#     fold   dataset                                             policy  \
# 0      0  training  No Advertising: Spam, referral links, unsolici...
# 1      0  training  No Advertising: Spam, referral links, unsolici...
# 2      0  training  No Advertising: Spam, referral links, unsolici...
# 3      0  training  No legal advice: Do not offer or request legal...
# 4      0  training  No legal advice: Do not offer or request legal...
# 5      0  training  No legal advice: Do not offer or request legal...
# 6      0     query  No Advertising: Spam, referral links, unsolici...
# 7      0     query  No Advertising: Spam, referral links, unsolici...
# 8      0     query  No Advertising: Spam, referral links, unsolici...
# 9      1  training  No Advertising: Spam, referral links, unsolici...
# 10     1  training  No Advertising: Spam, referral links, unsolici...
# 11     1  training  No Advertising: Spam, referral links, unsolici...
# ...

# %% [markdown]
# ## 6. Probability quality and distinct local metrics
#
# AUC can improve while probability calibration worsens. Brier and log loss are diagnostics; macro, pooled and ranked pooled AUC are not hidden Kaggle results.

# %%
display(pd.DataFrame(result["pooled_metrics"]))
CHARTS[6].show(renderer="plotly_mimetype")
CHARTS[7].show(renderer="plotly_mimetype")
# Out:
#               variant  macro_auc  pooled_auc  ranked_pooled_auc
# 0     lexical_control   0.657508    0.641345           0.650247
# 1        add_behavior   0.679862    0.680777           0.681784
# 2       add_act_roles   0.686099    0.691055           0.690944
# 3        copy_lexical   0.684815    0.690370           0.690285
# 4   condition_lexical   0.694518    0.698787           0.698227
# 5           rule_both   0.702246    0.709424           0.708569
# 6    copy_attribution   0.705409    0.712910           0.711981
# 7   scope_attribution   0.704944    0.712551           0.711575
# 8       copy_negation   0.705409    0.712910           0.711981
# 9      scope_negation   0.705614    0.712815           0.711871
# 10          copy_both   0.708476    0.715341           0.714592
# 11         scope_both   0.708098    0.714940           0.714017

# %% [markdown]
# ## 7. Fixed decision, caveats and durable outputs
#
# Require at least +0.003 mean AUC, positive simultaneous bounds, and no policy regression against both comparators. Passing means further-validation eligibility only. Scope research motivates the representation; [CheckList](https://aclanthology.org/2020.acl-main.442/) motivates the authored tests. See the included methodology for sources and limits.

# %%
for requirement in result["primary_requirements"]:
    display(pd.DataFrame([requirement["contrast"]]))
    print("Reference:", requirement["reference"], "| Per-policy changes:", requirement["per_policy_delta"])
print("Decision:", result["decision"])
for limitation in result["limitations"]:
    print(limitation)
print("Dashboard:", write_dashboard(ROOT, result))
print("Private checkpoints:", ROOT / "runs/scope_lexical_features" / result["run_id"])
# Out:
#                               comparison   candidate  reference  delta_auc  \
# 0  scope_both vs lexical evidence anchor  scope_both  rule_both   0.005851
#
#    simultaneous_low  simultaneous_high  valid_draws
# 0         -0.002177            0.01388          500
# Reference: rule_both | Per-policy changes: [0.00679104477611947, 0.0049118412555526625]
#                      comparison   candidate  reference  delta_auc  \
# 0  Scope versus collapsed: both  scope_both  copy_both  -0.000379
#
#    simultaneous_low  simultaneous_high  valid_draws
# 0         -0.008407            0.00765          500
# Reference: copy_both | Per-policy changes: [7.462686567172305e-05, -0.0008316862683703796]
# Decision: DO_NOT_PROMOTE_PRIMARY
# Adaptive exploratory follow-up; not an independent holdout.
# The Round 4 anchor was not promoted.
# Existing training-derived vocabulary, IDF and evidence weights.
# Token scope has no access to row targets or external models.
# ...
